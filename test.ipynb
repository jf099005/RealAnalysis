# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 1)
f1 = x
f2 = -np.log(1-x)
plt.plot(x, f1, label = 'y=x')
plt.plot(x, f2, label = 'y=log x')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_74863/780324472.py:5: RuntimeWarning: divide by zero encountered in log
#   f2 = -np.log(1-x)
